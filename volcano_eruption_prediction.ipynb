# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/volcano_eruption_prediction_2000.csv")
df.head()
# Out:
#    Seismic_Activity  Ground_Deformation  Gas_Emissions    Pressure  \
# 0          3.745401           -2.382943     285.997939  683.431259
# 1          9.507143           -2.530212     402.716165  255.147726
# 2          7.319939            4.062546     380.080465  885.155107
# 3          5.986585           -2.504538      76.949952  651.804615
# 4          1.560186           -2.280503      74.624735  241.483495
#
#    Temperature    Rainfall  Wind_Speed   Humidity  Population_Density  \
# 0    36.608038  112.092246   32.715316  25.854008            4.401609
# 1    35.618490   99.873629    4.001628  27.158271            0.330159
# 2    17.872626   52.846174   12.116491  72.157897          472.263461
# 3    42.677172  182.180001   38.683967  58.955257           29.293705
# 4    32.054166  142.987248   26.434293  83.233220          974.532554
#
#    Previous_Eruptions  Eruption_Predicted
# 0                   1                   0
# 1                   1                   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Seismic_Activity    2000 non-null   float64
#  1   Ground_Deformation  2000 non-null   float64
#  2   Gas_Emissions       2000 non-null   float64
#  3   Pressure            2000 non-null   float64
#  4   Temperature         2000 non-null   float64
#  5   Rainfall            2000 non-null   float64
#  6   Wind_Speed          2000 non-null   float64
#  7   Humidity            2000 non-null   float64
#  8   Population_Density  2000 non-null   float64
#  9   Previous_Eruptions  2000 non-null   int64
#  10  Eruption_Predicted  2000 non-null   int64
# dtypes: float64(9), int64(2)
# memory usage: 172.0 KB

# %%
df.describe()
# Out:
#        Seismic_Activity  Ground_Deformation  Gas_Emissions     Pressure  \
# count       2000.000000         2000.000000    2000.000000  2000.000000
# mean           4.986369           -0.036096     248.142453   539.055756
# std            2.922108            2.885799     143.970525   258.582896
# min            0.032183           -4.999884       0.015359   100.216904
# 25%            2.380465           -2.492132     123.467566   315.397134
# 50%            5.073513           -0.073057     245.755373   535.778937
# 75%            7.506788            2.486905     369.925889   763.420254
# max            9.997177            4.995577     499.675150   999.514613
#
#        Temperature     Rainfall   Wind_Speed     Humidity  Population_Density  \
# count  2000.000000  2000.000000  2000.000000  2000.000000         2000.000000
# mean     29.749375   151.641493    24.775979    59.835364          510.665188
# std       8.465109    87.383979    14.540734    23.223777          284.656346
# ...

# %%
df.isnull().sum()
# Out:
# Seismic_Activity      0
# Ground_Deformation    0
# Gas_Emissions         0
# Pressure              0
# Temperature           0
# Rainfall              0
# Wind_Speed            0
# Humidity              0
# Population_Density    0
# Previous_Eruptions    0
# Eruption_Predicted    0
# dtype: int64

# %%
x = df.drop(columns=["Eruption_Predicted"])
x
# Out:
#       Seismic_Activity  Ground_Deformation  Gas_Emissions    Pressure  \
# 0             3.745401           -2.382943     285.997939  683.431259
# 1             9.507143           -2.530212     402.716165  255.147726
# 2             7.319939            4.062546     380.080465  885.155107
# 3             5.986585           -2.504538      76.949952  651.804615
# 4             1.560186           -2.280503      74.624735  241.483495
# ...                ...                 ...            ...         ...
# 1995          6.569552           -0.578930     342.217681  345.843658
# 1996          9.566146           -1.655988     251.610207  288.567302
# 1997          0.689580           -1.054277     382.574425  509.795875
# 1998          0.570547            0.299406     242.645317  917.593793
# 1999          2.821871           -3.386326      74.690818  194.032285
#
#       Temperature    Rainfall  Wind_Speed   Humidity  Population_Density  \
# ...

# %%
y = df["Eruption_Predicted"]
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# Name: Eruption_Predicted, Length: 2000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy = accuracy_score(ytest, ypred)
class_report = classification_report(ytest, ypred)

# Print results
print("Model Accuracy:", accuracy)
print("Classification Report:\n", class_report)
# Out:
# Model Accuracy: 0.84
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       336
#            1       0.00      0.00      0.00        64
#
#     accuracy                           0.84       400
#    macro avg       0.42      0.50      0.46       400
# weighted avg       0.71      0.84      0.77       400
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# prompt: create a pikle file of LogisticRegression

import pickle
filename = 'finalized_model.sav'
pickle.dump(model, open(filename, 'wb'))

# some time later...

# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(xtest, ytest)
result
